# %%
import pandas as pd

# %%
def read_in_chunks(file_path, sep='\t'):
    chunk_size = 1000  # adjust as needed
    chunks = pd.read_csv(file_path, sep=sep, chunksize=chunk_size)
    df = pd.concat(chunks)
    return df

# %%
tsv_file_paths = ['Data/name.basics.tsv', 'Data/title.akas.tsv', 
                 'Data/title.basics.tsv', 'Data/title.principals.tsv', 
                 'Data/title.ratings.tsv']
dfs = []
for file_path in tsv_file_paths:
    df = read_in_chunks(file_path)
    dfs.append(df)

# %%
df1 = dfs[0]
df2 = dfs[1]
df3 = dfs[2]
df4 = dfs[3]
df5 = dfs[4]

# %%
df6 = pd.read_json('Data/IMDB_reviews.json', lines=True)
df7 = pd.read_json('Data/IMDB_movie_details.json', lines=True)

# %%
df1.head(3)
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934        \N
#
#                     primaryProfession                           knownForTitles
# 0        actor,miscellaneous,producer  tt0072308,tt0050419,tt0053137,tt0027125
# 1  actress,soundtrack,archive_footage  tt0037382,tt0075213,tt0117057,tt0038355
# 2   actress,music_department,producer  tt0057345,tt0049189,tt0056404,tt0054452

# %% [markdown]
# df1 contains people who have worked on or in movies.

# %%
df2.head(3)
# Out:
#      titleId  ordering       title region language        types  \
# 0  tt0000001         1  Carmencita     \N       \N     original
# 1  tt0000001         2  Carmencita     DE       \N           \N
# 2  tt0000001         3  Carmencita     US       \N  imdbDisplay
#
#       attributes  isOriginalTitle
# 0             \N                1
# 1  literal title                0
# 2             \N                0

# %% [markdown]
# df2 contains movie id and different names for the same movie

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48348097 entries, 0 to 48348096
# Data columns (total 8 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   titleId          object
#  1   ordering         int64
#  2   title            object
#  3   region           object
#  4   language         object
#  5   types            object
#  6   attributes       object
#  7   isOriginalTitle  int64
# dtypes: int64(2), object(6)
# memory usage: 2.9+ GB

# %%
df2.replace('\\N', pd.NA, inplace=True)

# %%
df2.isnull().sum()
# Out:
# titleId                   0
# ordering                  0
# title                    35
# region             10843862
# language           15984678
# types              33488143
# attributes         48068847
# isOriginalTitle           0
# dtype: int64

# %%
df2.drop('attributes', axis=1, inplace=True)

# %%
df2.drop('ordering', axis=1, inplace=True)

# %%
df2['types'].unique()
# Out:
# array(['original', <NA>, 'imdbDisplay', 'alternative', 'festival', 'dvd',
#        'working', 'tv', 'video', 'imdbDisplay\x02tv', 'alternative\x02tv',
#        'imdbDisplay\x02working', 'imdbDisplay\x02festival',
#        'working\x02tv', 'imdbDisplay\x02video', 'dvd\x02alternative',
#        'tv\x02video', 'imdbDisplay\x02dvd', 'working\x02video',
#        'working\x02festival', 'dvd\x02video', 'alternative\x02festival',
#        'alternative\x02video', 'working\x02alternative'], dtype=object)

# %%
df3.head(3)
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              5  Animation,Comedy,Romance

# %% [markdown]
# df3 is movies and their years and genres

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10790736 entries, 0 to 10790735
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 740.9+ MB

# %%
df3.replace('\\N', pd.NA, inplace=True)

# %%
df3.isnull().sum()
# Out:
# tconst                   0
# titleType                0
# primaryTitle            19
# originalTitle           19
# isAdult                  1
# startYear          1406804
# endYear           10666898
# runtimeMinutes     7443113
# genres              480417
# dtype: int64

# %%
df3.drop('endYear', axis=1, inplace=True)

# %%
df4.head(3)
# Out:
#       tconst  ordering     nconst  category       job characters
# 0  tt0000001         1  nm1588970      self        \N   ["Self"]
# 1  tt0000001         2  nm0005690  director        \N         \N
# 2  tt0000001         3  nm0005690  producer  producer         \N

# %% [markdown]
# df4 is the movies and actor relationship

# %%
df5.head(3)
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2058
# 1  tt0000002            5.7       276
# 2  tt0000003            6.5      2015

# %% [markdown]
# df5 is avg rating and number of votes per movie

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1439968 entries, 0 to 1439967
# Data columns (total 3 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   tconst         1439968 non-null  object
#  1   averageRating  1439968 non-null  float64
#  2   numVotes       1439968 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 33.0+ MB

# %%
df6.head(3)
# Out:
#         review_date   movie_id    user_id  is_spoiler  \
# 0  10 February 2006  tt0111161  ur1898687        True
# 1  6 September 2000  tt0111161  ur0842118        True
# 2     3 August 2001  tt0111161  ur1285640        True
#
#                                          review_text  rating  \
# 0  In its Oscar year, Shawshank Redemption (writt...      10
# 1  The Shawshank Redemption is without a doubt on...      10
# 2  I believe that this film is the best story eve...       8
#
#                                   review_summary
# 0  A classic piece of unforgettable film-making.
# 1     Simply amazing. The best film of the 90's.
# 2               The best story ever told on film

# %%
user_id_column = df6['user_id']
new_df = pd.DataFrame(user_id_column, columns=['user_id'])
new_df.to_csv('user_ids.csv', index=False)

# %%
df7.head(3)
# Out:
#     movie_id                                       plot_summary  duration  \
# 0  tt0105112  Former CIA analyst, Jack Ryan is in England wi...  1h 57min
# 1  tt1204975  Billy (Michael Douglas), Paddy (Robert De Niro...  1h 45min
# 2  tt0243655  The setting is Camp Firewood, the year 1981. I...  1h 37min
#
#                 genre  rating release_date  \
# 0  [Action, Thriller]     6.9   1992-06-05
# 1            [Comedy]     6.6   2013-11-01
# 2   [Comedy, Romance]     6.7   2002-04-11
#
#                                        plot_synopsis
# 0  Jack Ryan (Ford) is on a "working vacation" in...
# 1  Four boys around the age of 10 are friends in ...
# 2

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1572 entries, 0 to 1571
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   movie_id       1572 non-null   object
#  1   plot_summary   1572 non-null   object
#  2   duration       1572 non-null   object
#  3   genre          1572 non-null   object
#  4   rating         1572 non-null   float64
#  5   release_date   1572 non-null   object
#  6   plot_synopsis  1572 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 98.2+ KB

# %% [markdown]
# ## Database structure
#
# MsSQL: User table, movies table, payment_detail table (with ids)
#
# MongoDB: Reviews, recommendations
#
# Neo4j: Actors relationship, users relationships

# %% [markdown]
# ## MsSQL
#
# Movie: id, title, alternative titles, duration, plot_Summary, genre, realease_date/start year, rating/avg_rating

# %% [markdown]
# User: id, username, password, email, first_name, last_name, payment_details, friends that they follow, relationship to movies and reviews,

# %%
# !pip install pyodbc

# %%
# !pip install sqlalchemy pymssql

# %% [markdown]
# USER TABLE

# %%
import pandas as pd

# Read the CSV file
df_users = pd.read_csv('Data/users.csv')

# %%
df_users
# Out:
#        user_id     username        password                        email  \
# 0    ur1898687     johndoe1     P@ssw0rd123        john.doe1@example.com
# 1    ur0842118    janesmith     J@n3Smit#45       jane.smith@example.com
# 2    ur1285640     jimbrown     Br0wnie#789        jim.brown@example.com
# 3    ur1003471  jilljohnson     J!llybean76     jill.johnson@example.com
# 4    ur0226855    jackwhite    Wh!teH0rse22       jack.white@example.com
# ..         ...          ...             ...                          ...
# 196  ur3402930      josephd    J0s3phD3W!tt    joseph.dewitt@example.com
# 197  ur2389420     richardb     R!ch@rdB@ss      rchard.bass@example.com
# 198  ur2039203      laurenc  L@ur3nC@mpb3ll  lauren.campbell@example.com
# 199  ur0000001     cph-caro            1234            cphcaro@gmail.com
# 200  ur0000002     cph-mari            1234            cphmari@gmail.com
#
#     first_name last_name payment_details        role
# ...

# %% [markdown]
# ## Making movies table

# %%
# Merge the two DataFrames on the "movie_id" and "tconst" columns
merged_df = pd.merge(df7, df3[['tconst', 'primaryTitle', 'originalTitle']], left_on='movie_id', right_on='tconst', how='left')

# Drop the redundant 'tconst' column if needed
merged_df = merged_df.drop(columns=['tconst'])

# Display the first few rows of the merged DataFrame
print(merged_df.head())
# Out:
#     movie_id                                       plot_summary  duration  \
# 0  tt0105112  Former CIA analyst, Jack Ryan is in England wi...  1h 57min
# 1  tt1204975  Billy (Michael Douglas), Paddy (Robert De Niro...  1h 45min
# 2  tt0243655  The setting is Camp Firewood, the year 1981. I...  1h 37min
# 3  tt0040897  Fred C. Dobbs and Bob Curtin, both down on the...   2h 6min
# 4  tt0126886  Tracy Flick is running unopposed for this year...  1h 43min
#
#                          genre  rating release_date  \
# 0           [Action, Thriller]     6.9   1992-06-05
# 1                     [Comedy]     6.6   2013-11-01
# 2            [Comedy, Romance]     6.7   2002-04-11
# 3  [Adventure, Drama, Western]     8.3   1948-01-24
# 4     [Comedy, Drama, Romance]     7.3   1999-05-07
#
#                                        plot_synopsis  \
# 0  Jack Ryan (Ford) is on a "working vacation" in...
# 1  Four boys around the age of 10 are friends in ...
# 2
# ...

# %%
merged_df
# Out:
#         movie_id                                       plot_summary  duration  \
# 0      tt0105112  Former CIA analyst, Jack Ryan is in England wi...  1h 57min
# 1      tt1204975  Billy (Michael Douglas), Paddy (Robert De Niro...  1h 45min
# 2      tt0243655  The setting is Camp Firewood, the year 1981. I...  1h 37min
# 3      tt0040897  Fred C. Dobbs and Bob Curtin, both down on the...   2h 6min
# 4      tt0126886  Tracy Flick is running unopposed for this year...  1h 43min
# ...          ...                                                ...       ...
# 1567   tt0289879  Evan Treborn grows up in a small town with his...  1h 53min
# 1568   tt1723811  Brandon is a 30-something man living in New Yo...  1h 41min
# 1569   tt5013056  Evacuation of Allied soldiers from the British...  1h 46min
# 1570  tt0104014/  For a while now, beautiful 24-year-old Diana B...  1h 33min
# 1571  tt0114142/  The marriage of David Burgess, a senior execut...  1h 32min
#
# ...

# %%
# Rename the columns
merged_df = merged_df.rename(columns={'primaryTitle': 'primary_title', 'originalTitle': 'original_title'})


# Define the desired column order
desired_order = ['movie_id', 'primary_title', 'original_title','plot_summary',
                 'duration', 'genre', 'rating', 'release_date', 'plot_synopsis'] + [col for col in merged_df.columns if col not in ['movie_id', 'primary_title', 'original_title','plot_summary',
                 'duration', 'genre', 'rating', 'release_date', 'plot_synopsis']]

# Reorder the DataFrame
merged_df = merged_df[desired_order]

# %%
# Save the result to a new CSV file
#merged_df.to_csv('merged_dataset.csv', index=False)

merged_df
# Out:
#         movie_id                     primary_title  \
# 0      tt0105112                     Patriot Games
# 1      tt1204975                        Last Vegas
# 2      tt0243655           Wet Hot American Summer
# 3      tt0040897  The Treasure of the Sierra Madre
# 4      tt0126886                          Election
# ...          ...                               ...
# 1567   tt0289879              The Butterfly Effect
# 1568   tt1723811                             Shame
# 1569   tt5013056                           Dunkirk
# 1570  tt0104014/                               NaN
# 1571  tt0114142/                               NaN
#
#                         original_title  \
# 0                        Patriot Games
# 1                           Last Vegas
# 2              Wet Hot American Summer
# 3     The Treasure of the Sierra Madre
# 4                             Election
# ...                                ...
# 1567              The Butterfly Effect
# ...

# %%
merged_df1 = merged_df.drop(columns=['genre'])
merged_df1
# Out:
#         movie_id                     primary_title  \
# 0      tt0105112                     Patriot Games
# 1      tt1204975                        Last Vegas
# 2      tt0243655           Wet Hot American Summer
# 3      tt0040897  The Treasure of the Sierra Madre
# 4      tt0126886                          Election
# ...          ...                               ...
# 1567   tt0289879              The Butterfly Effect
# 1568   tt1723811                             Shame
# 1569   tt5013056                           Dunkirk
# 1570  tt0104014/                               NaN
# 1571  tt0114142/                               NaN
#
#                         original_title  \
# 0                        Patriot Games
# 1                           Last Vegas
# 2              Wet Hot American Summer
# 3     The Treasure of the Sierra Madre
# 4                             Election
# ...                                ...
# 1567              The Butterfly Effect
# ...

# %%
merged_df1.to_csv('merged_dataset_ex_genre.csv', index=False)

# %%
merged_df
# Out:
#         movie_id                     primary_title  \
# 0      tt0105112                     Patriot Games
# 1      tt1204975                        Last Vegas
# 2      tt0243655           Wet Hot American Summer
# 3      tt0040897  The Treasure of the Sierra Madre
# 4      tt0126886                          Election
# ...          ...                               ...
# 1567   tt0289879              The Butterfly Effect
# 1568   tt1723811                             Shame
# 1569   tt5013056                           Dunkirk
# 1570  tt0104014/                               NaN
# 1571  tt0114142/                               NaN
#
#                         original_title  \
# 0                        Patriot Games
# 1                           Last Vegas
# 2              Wet Hot American Summer
# 3     The Treasure of the Sierra Madre
# 4                             Election
# ...                                ...
# 1567              The Butterfly Effect
# ...

# %% [markdown]
# ### Genre table

# %%
genre_series = merged_df['genre']

# Explode the list-like column into separate rows
genre_df = merged_df.explode('genre')

# Reset index to get continuous indices
genre_df = genre_df.reset_index(drop=True)

# Create a new DataFrame for genres with a unique ID for each genre
genre_df = pd.DataFrame(genre_df['genre'].unique(), columns=['genre'])
genre_df['genre_id'] = ['gd{:07d}'.format(i+1) for i in range(len(genre_df))]


print(genre_df.head())
genre_df
# Out:
#        genre   genre_id
# 0     Action  gd0000001
# 1   Thriller  gd0000002
# 2     Comedy  gd0000003
# 3    Romance  gd0000004
# 4  Adventure  gd0000005
#         genre   genre_id
# 0      Action  gd0000001
# 1    Thriller  gd0000002
# 2      Comedy  gd0000003
# 3     Romance  gd0000004
# 4   Adventure  gd0000005
# 5       Drama  gd0000006
# 6     Western  gd0000007
# 7      Sci-Fi  gd0000008
# 8     Fantasy  gd0000009
# 9      Family  gd0000010
# 10      Sport  gd0000011
# 11     Horror  gd0000012
# 12      Crime  gd0000013
# 13        War  gd0000014
# 14    Mystery  gd0000015
# 15  Biography  gd0000016
# 16    History  gd0000017
# 17      Music  gd0000018
# 18  Animation  gd0000019
# 19    Musical  gd0000020
# 20  Film-Noir  gd0000021

# %%
# Save the new genre DataFrame to a CSV file
genre_df.to_csv('genre_dataset.csv', index=False)

# %% [markdown]
# ### Creating Movie-Genre table

# %%
merged_df['movie_id'] = merged_df['movie_id'].str.rstrip('/')

# Explode the list-like column into separate rows to ensure each movie has multiple rows corresponding to its genres
exploded_df = merged_df.explode('genre')

# Merge with genre_df to get genre_id for each genre
genre_id_mapping = pd.merge(exploded_df, genre_df, left_on='genre', right_on='genre', how='left')

# Select only the movie_id and genre_id columns
movie_genre_mapping = genre_id_mapping[['movie_id', 'genre_id']]

print(movie_genre_mapping.head())
# Out:
#     movie_id   genre_id
# 0  tt0105112  gd0000001
# 1  tt0105112  gd0000002
# 2  tt1204975  gd0000003
# 3  tt0243655  gd0000003
# 4  tt0243655  gd0000004

# %%
movie_genre_mapping
# Out:
#        movie_id   genre_id
# 0     tt0105112  gd0000001
# 1     tt0105112  gd0000002
# 2     tt1204975  gd0000003
# 3     tt0243655  gd0000003
# 4     tt0243655  gd0000004
# ...         ...        ...
# 4120  tt5013056  gd0000017
# 4121  tt0104014  gd0000003
# 4122  tt0104014  gd0000006
# 4123  tt0114142  gd0000006
# 4124  tt0114142  gd0000002
#
# [4125 rows x 2 columns]

# %%
# Save the movie-genre mapping dataset to a CSV file
movie_genre_mapping.to_csv('movie_genre_mapping.csv', index=False)

# %%
cursor = conn.cursor()

# SQL query to create table
create_table_query = '''
CREATE TABLE movie_test (
    movie_id VARCHAR PRIMARY KEY,
    plot_summary TEXT,
    duration TEXT,
    genre TEXT,
    rating FLOAT,
    release_date TEXT,
    plot_synopsis TEXT
);
'''

##CREATE TABLE movie_test (
    #movie_id VARCHAR PRIMARY KEY,
    #primary_title,
    #orginal_title,
    #plot_summary TEXT,
    #duration TEXT,
    #rating FLOAT,
    #release_date TEXT,
    #plot_synopsis TEXT
#);

# Execute the SQL query to create the table
cursor.execute(create_table_query)

# Commit the changes
conn.commit()

# Close the cursor and connection
cursor.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 cursor = conn.cursor()
#       3 # SQL query to create table
#       4 create_table_query = '''
#       5 CREATE TABLE movie_test (
#       6     movie_id VARCHAR PRIMARY KEY,
#    (...)
#      13 );
#      14 '''
#
# NameError: name 'conn' is not defined

# %% [markdown]
# USER TABLE:
#
# ROLES = viewer, certified, admin

# %% [markdown]
# GENRE TABLE:
#
# Genres = action, thriller, comedy, romance, drama, western, adventure, action, sci-fi, fantasy,
# family, horror, sport, crime, war, mystery,
